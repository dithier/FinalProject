# %%
#https://github.com/frc1418/tbapy/blob/master/tbapy/main.py
import requests
URL= "https://www.thebluealliance.com/api/v3/event/2018nhdur/teams"
auth_key = 'fge7icVbwIkRUkYKFb7Bj045jGELlWspOnCTxJnhkC9jqiLRjE0VBR4ACcez4vxo'

# https://www.dataquest.io/blog/python-api-tutorial/
# https://www.digitalocean.com/community/tutorials/how-to-use-web-apis-in-python-3
# https://www.dataquest.io/blog/python-api-tutorial/
# https://www.dataquest.io/blog/python-api-tutorial/
headers = {"X-TBA-Auth-Key": auth_key}
response = requests.get(URL, headers = headers)
data = response.json()
data
# Out:
# [{'address': None,
#   'city': 'Wolcott',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc1071',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'To The MAX',
#   'name': 'UTC/Lockheed Martin SIkorsky/Wolcott Board of Education &Wolcott High School',
#   'nickname': 'Team Max',
#   'postal_code': '06716',
#   'rookie_year': 2003,
#   'state_prov': 'Connecticut',
#   'team_number': 1071,
#   'website': 'http://www.max1071.com'},
#  {'address': None,
#   'city': 'Hollis',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc1073',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Sanity is Optional',
#   'name': 'UTC/Waters Corporation/Parker Hannifin/Diamond Casting/BAE Systems&Hollis-Brookline High School',
#   'nickname': 'The Force Team',
#   'postal_code': '03049',
#   'rookie_year': 2003,
#   'state_prov': 'New Hampshire',
#   'team_number': 1073,
#   'website': 'http://www.theforceteam.com'},
#  {'address': None,
#   'city': 'North Sutton',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc1247',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'NDEP/Hypertherm & Kearsarge Regional High School',
#   'nickname': 'Blood, Sweat, and Gears',
#   'postal_code': '03260',
#   'rookie_year': 2004,
#   'state_prov': 'New Hampshire',
#   'team_number': 1247,
#   'website': 'http://www.roksbot.com'},
#  {'address': None,
#   'city': 'Dover',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc1307',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'St Thomas Aquinas High School',
#   'nickname': 'Robosaints',
#   'postal_code': '03820',
#   'rookie_year': 2004,
#   'state_prov': 'New Hampshire',
#   'team_number': 1307,
#   'website': 'http://www.firstinspires.org/'},
#  {'address': None,
#   'city': 'Manchester',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc131',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': "You can't stop us!",
#   'name': 'BAE SYSTEMS/Rockwell Automation/Solid Works/CHAOS Families/Cronin Bisson & Zalinsky, Attorneys at Law/C.H.A.O.S Alumni/Queen City Rotary Club&Manchester Central High School&4-H Hillsborough County, NH',
#   'nickname': 'C.H.A.O.S.',
#   'postal_code': '03104',
#   'rookie_year': 1992,
#   'state_prov': 'New Hampshire',
#   'team_number': 131,
#   'website': 'http://www.chaos131.com'},
#  {'address': None,
#   'city': 'Amherst',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc138',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'We Love Torque',
#   'name': 'Monarch Instrument / Rockwell Automation / BAE Systems / SvenGrafik / Control Air / John Alberts Welding / Rapid Sheet Metal / Amherst Lions Club / County Stores / BB Mold & Souhegan Coop High School',
#   'nickname': 'Entropy',
#   'postal_code': '03031',
#   'rookie_year': 1996,
#   'state_prov': 'New Hampshire',
#   'team_number': 138,
#   'website': 'http://www.robotics138.org'},
#  {'address': None,
#   'city': 'Nashua',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc151',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Where all students go pro',
#   'name': 'MakeIt Labs/GHO Ventures/Parker Hannifin/Benchmark Electronics/BAE Systems/3rd Degree Safety Solutions/Northeast Delta Dental/Think For Fun/RBC Generational Wealth Management Group/Pat Clancy Realty LLC&Family/Community',
#   'nickname': 'Tough Techs',
#   'postal_code': '03062',
#   'rookie_year': 1992,
#   'state_prov': 'New Hampshire',
#   'team_number': 151,
#   'website': 'http://www.nashua151.org'},
#  {'address': None,
#   'city': 'Concord',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc1512',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': "Criterium-Turner Engineers/Penn Engineering/Plano Molding Company&St Paul'S School",
#   'nickname': 'The Big Red',
#   'postal_code': '03301',
#   'rookie_year': 2005,
#   'state_prov': 'New Hampshire',
#   'team_number': 1512,
#   'website': 'http://robotics.sps.edu'},
#  {'address': None,
#   'city': 'Milford',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc1519',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Let the MAYHEM begin!',
#   'name': 'BAE Systems/Cirtronics/Rockwell Automation/Altium&Milford Area Youth Homeschoolers Enriching Minds',
#   'nickname': 'Mechanical Mayhem',
#   'postal_code': '03055',
#   'rookie_year': 2005,
#   'state_prov': 'New Hampshire',
#   'team_number': 1519,
#   'website': 'http://www.mechanicalmayhem.org/'},
#  {'address': None,
#   'city': 'Merrimack',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc166',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Wicked Awesome',
#   'name': 'BAE Systems/The Bull Family/Raytheon/DDG Fabrication/John Albert Welding Services/B & K Industrial Finishing, Inc. &Merrimack High School',
#   'nickname': 'Chop Shop',
#   'postal_code': '03054',
#   'rookie_year': 1995,
#   'state_prov': 'New Hampshire',
#   'team_number': 166,
#   'website': 'http://www.chopshop166.com'},
#  {'address': None,
#   'city': 'Colchester',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc1699',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Dominion Nuclear Connecticut Inc./United Technologies/Colchester Lions Club & Bacon Academy',
#   'nickname': 'Robocats',
#   'postal_code': '06415',
#   'rookie_year': 2005,
#   'state_prov': 'Connecticut',
#   'team_number': 1699,
#   'website': 'http://robocats.wix.com/team1699robocats'},
#  {'address': None,
#   'city': 'Concord',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc1721',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'We built... We programmed... We Concord.',
#   'name': "Atrium/Spain Family/Cordova Family/BAE Systems/Boston Scientific/Concord Rotary Club/Granite State Naturals/Terrance Macaig/Cimo's South End Deli&Concord High School",
#   'nickname': 'Tidal Force',
#   'postal_code': '03301',
#   'rookie_year': 2006,
#   'state_prov': 'New Hampshire',
#   'team_number': 1721,
#   'website': 'http://www.frc1721.org/'},
#  {'address': None,
#   'city': 'Dublin',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc1786',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Truth and Courage',
#   'name': 'Dublin School',
#   'nickname': 'The Robotics Team',
#   'postal_code': '03444',
#   'rookie_year': 2006,
#   'state_prov': 'New Hampshire',
#   'team_number': 1786,
#   'website': 'http://www.firstinspires.org/'},
#  {'address': None,
#   'city': 'Keene',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc213',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Dirty Birds Get it Done!',
#   'name': 'Symbotic/The Argosy Foundation and Boeing Grant/Whelen Engineering/Timken Aerospace&Keene High School',
#   'nickname': 'The Dirty Birds',
#   'postal_code': '03431',
#   'rookie_year': 1999,
#   'state_prov': 'New Hampshire',
#   'team_number': 213,
#   'website': 'http://www.firstinspires.org/'},
#  {'address': None,
#   'city': 'Alton',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc319',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'take it apart, put it back together, beat our time',
#   'name': 'Symbotic/SPS New England/Podmore Manufacturing/NDEP/OPTICS 1&Prospect Mountain High School',
#   'nickname': 'Big Bad Bob',
#   'postal_code': '03809',
#   'rookie_year': 1999,
#   'state_prov': 'New Hampshire',
#   'team_number': 319,
#   'website': 'http://www.frc319.com'},
#  {'address': None,
#   'city': 'Litchfield',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc3323',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Position is Power',
#   'name': 'Litchfield School District/BAE SYSTEMS/Continental Paving/Robinson Precision Tool/FWM Inc./Parker/Solidworks&Campbell High School',
#   'nickname': 'Potential Energy',
#   'postal_code': '03052',
#   'rookie_year': 2010,
#   'state_prov': 'New Hampshire',
#   'team_number': 3323,
#   'website': 'http://pe3323.weebly.com/'},
#  {'address': None,
#   'city': 'Sanford',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc3451',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Determine how strong you need it, then double it. ',
#   'name': 'United Technologies/Robotics Institute of Maine/DOD STEM/Caron Engineering/Pratt & Whitney&Sanford Regional Technical Center',
#   'nickname': 'The ANOMALY',
#   'postal_code': '04073',
#   'rookie_year': 2011,
#   'state_prov': 'Maine',
#   'team_number': 3451,
#   'website': 'http://sanford.mainecte.org/program/pre-engineeringrobotics/'},
#  {'address': None,
#   'city': 'Durham',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc3499',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Get back to work, stop arguing about pizza.',
#   'name': 'OYSTER RIVER HIGH SCHOOL',
#   'nickname': "River's Edge Robotics",
#   'postal_code': '03824',
#   'rookie_year': 2011,
#   'state_prov': 'New Hampshire',
#   'team_number': 3499,
#   'website': None},
#  {'address': None,
#   'city': 'Kittery',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc3597',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Life begins at the end of your comfort zone',
#   'name': 'United Technologies / Pratt & Whitney / Robotic Institute of Maine / National Defense Education Program / Portsmouth Naval Shipyard & Robert W Traip Academy',
#   'nickname': 'Robo-Rangers',
#   'postal_code': '03904',
#   'rookie_year': 2011,
#   'state_prov': 'Maine',
#   'team_number': 3597,
#   'website': 'http://rangers.rwtraip.kittery.k12.me.us/~robotics/Robotics/Home.html'},
#  {'address': None,
#   'city': 'Portland',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc3609',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Should be fine',
#   'name': 'Robotics Institute of Maine/Coast City Comics/PTC&Boys and Girls Club Portland',
#   'nickname': 'Duct Tape Dragons',
#   'postal_code': '04101',
#   'rookie_year': 2011,
#   'state_prov': 'Maine',
#   'team_number': 3609,
#   'website': 'http://bgcmaine.org'},
#  {'address': None,
#   'city': 'Dover',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc4546',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'In bot we trust',
#   'name': 'ArgenTech Solutions/Comcast/NDEP/Portsmouth Naval Shipyard/Duckworks Engineering & Dover Senior High School',
#   'nickname': 'ShockWave',
#   'postal_code': '03820',
#   'rookie_year': 2013,
#   'state_prov': 'New Hampshire',
#   'team_number': 4546,
#   'website': 'https://www.dovershockwave.org/'},
#  {'address': None,
#   'city': 'Skowhegan',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc4555',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Robotic Institute of Maine/Army National Guard/Underwriters Laboratory & Somerset Career & Technical Center',
#   'nickname': 'Sprocketology',
#   'postal_code': '04976',
#   'rookie_year': 2013,
#   'state_prov': 'Maine',
#   'team_number': 4555,
#   'website': 'http://www.firstinspires.org/'},
#  {'address': None,
#   'city': 'Wolfeboro',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc4925',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Governor Wentworth Regional School District / Vanderheiden Foundation / United Technologies / Town of Middleton / Meredith Village Savings Bank  & Kingswood Regional High School',
#   'nickname': 'The Resistance ',
#   'postal_code': '03894',
#   'rookie_year': 2014,
#   'state_prov': 'New Hampshire',
#   'team_number': 4925,
#   'website': 'https://sites.google.com/a/student.govwentworth.k12.nh.us/the-resistance-4925/'},
#  {'address': None,
#   'city': 'Haverhill',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc4929',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Success is measured by the strength of our team',
#   'name': 'Schneider Electric/Raytheon/BAE Systems & Whittier Reg Voc',
#   'nickname': 'Maroon Monsoon',
#   'postal_code': '01830',
#   'rookie_year': 2014,
#   'state_prov': 'Massachusetts',
#   'team_number': 4929,
#   'website': 'http://www.firstinspires.org/'},
#  {'address': None,
#   'city': 'Langdon',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc4958',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'First Robotics Competition/Whelen Engineering/FMEEA &Fall Mountain Regional High School',
#   'nickname': 'Robocats',
#   'postal_code': '03609',
#   'rookie_year': 2014,
#   'state_prov': 'New Hampshire',
#   'team_number': 4958,
#   'website': 'https://sites.google.com/a/apps.sau60.org/fmrhs/robotics'},
#  {'address': None,
#   'city': 'Manchester',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc501',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Meeting the challenge, exceeding the standard.',
#   'name': 'BURNDY/UL/4-H & 4-H & Manchester West High School & Goffstown High School',
#   'nickname': 'The PowerKnights',
#   'postal_code': '03102',
#   'rookie_year': 2001,
#   'state_prov': 'New Hampshire',
#   'team_number': 501,
#   'website': 'http://www.powerknights.com'},
#  {'address': None,
#   'city': 'Bedford',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc509',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Taking the World by STORM',
#   'name': 'Bedford School District & Bedford High School',
#   'nickname': 'Red Storm',
#   'postal_code': '03110',
#   'rookie_year': 2001,
#   'state_prov': 'New Hampshire',
#   'team_number': 509,
#   'website': 'http://www.redstorm509.appspot.com/'},
#  {'address': None,
#   'city': 'Westford',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc5422',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'SMC LTC/Creation Station, LLC/United Technologies (UTC)/Analog Devices/SolidWorks/RedHat/E.T. Duval & Sons/NetScout/Raytheon/Ekaru/Hunter Automation/Add-A-Sign, LLC/Rockwell Automation/Mathworks/Nichols Family/Bose/3DWox Sindoh/McCarty Companies/Northeast Promotion and Apparel/Panera Bread/Torriander&Middlesex County Robotics Club, Inc.',
#   'nickname': 'Stormgears FRC',
#   'postal_code': '01886',
#   'rookie_year': 2015,
#   'state_prov': 'Massachusetts',
#   'team_number': 5422,
#   'website': 'http://www.stormgears.org'},
#  {'address': None,
#   'city': 'Searsport',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc5506',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': '"Raising Aspirations, Raising Opportunities, Raising Success!"',
#   'name': "RSU #20/Robotics Institute of Maine/GitHub/Gabe Baker/Greg's Auto Sales&Searsport District High School",
#   'nickname': 'Midcoast MAINEiacs',
#   'postal_code': '04974',
#   'rookie_year': 2015,
#   'state_prov': 'Maine',
#   'team_number': 5506,
#   'website': 'http://www.midcoastmaineiacs.org'},
#  {'address': None,
#   'city': 'Bath',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc5633',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Maine Institute of Robotics/2015 FRC Rookie Grant & Hyde School',
#   'nickname': 'Hyde Cyber Wolves',
#   'postal_code': '04530',
#   'rookie_year': 2015,
#   'state_prov': 'Maine',
#   'team_number': 5633,
#   'website': 'http://www.firstinspires.org/'},
#  {'address': None,
#   'city': 'Concord',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc5813',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': 'Dream Big ',
#   'name': 'AAVID, Thermal Divsion of Boyd Corporation/Iron Dragon Corporation/Whitney Family/Murali Ravel, D.M.D., P.C./Allegro MicroSystems, LLC/BAE Systems/Rx Advance Corporation/SOLIDWORKS&Neighborhood Group',
#   'nickname': 'Morpheus',
#   'postal_code': '03301',
#   'rookie_year': 2016,
#   'state_prov': 'New Hampshire',
#   'team_number': 5813,
#   'website': 'http://5813.frc.team'},
#  {'address': None,
#   'city': 'Portsmouth',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc5902',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Analog Devices/Portsmouth Naval Shipyard/DoD STEM&New Heights&Portsmouth High School',
#   'nickname': 'The Wire Clippers',
#   'postal_code': '03801',
#   'rookie_year': 2016,
#   'state_prov': 'New Hampshire',
#   'team_number': 5902,
#   'website': 'http://www.newheightsonline.org'},
#  {'address': None,
#   'city': 'Boston',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc6367',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'NASA/Anchor Labs/H. E. Moore Corp.&Edward Brooke Charter School',
#   'nickname': 'The ElectroLights',
#   'postal_code': '02127',
#   'rookie_year': 2017,
#   'state_prov': 'Massachusetts',
#   'team_number': 6367,
#   'website': 'http://team6367.org'},
#  {'address': None,
#   'city': 'Concord',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc6690',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Gomez and Sullivan Engineers&Merrimack Valley High School',
#   'nickname': 'MV roboPride',
#   'postal_code': '03303',
#   'rookie_year': 2017,
#   'state_prov': 'New Hampshire',
#   'team_number': 6690,
#   'website': None},
#  {'address': None,
#   'city': 'Wolfeboro',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc6691',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'New Valence Robotics&Brewster Academy',
#   'nickname': 'Torque',
#   'postal_code': '03894',
#   'rookie_year': 2017,
#   'state_prov': 'New Hampshire',
#   'team_number': 6691,
#   'website': None},
#  {'address': None,
#   'city': 'Hillsborough',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc6762',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': "Osram/Duncan-Jenkins Trust/FIRST of NH Fund/Utopia Machine Works/Ferguson Tool and Instrument/BAE Systems/The Rotary Club of Henniker/Sons of the American Legion, Young and Richardson Squadron #59/Robert Hassett/John Oberti/Stella's Corner/Gibson Pewter/J. McCarthy Trust&Hillsboro-Deering High School",
#   'nickname': 'Oscats',
#   'postal_code': '03244',
#   'rookie_year': 2017,
#   'state_prov': 'New Hampshire',
#   'team_number': 6762,
#   'website': None},
#  {'address': None,
#   'city': 'Walpole',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc6895',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'NASA/Hypertherm HOPE Foundation/Applied Bolting Technology/The Kingsbury Fund&4-H',
#   'nickname': 'Mechanical Madness 4-H',
#   'postal_code': '03608',
#   'rookie_year': 2018,
#   'state_prov': 'New Hampshire',
#   'team_number': 6895,
#   'website': None},
#  {'address': None,
#   'city': 'Newmarket',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc7126',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Newmarket Jr.-Sr. High School',
#   'nickname': 'RoboMules',
#   'postal_code': '03857',
#   'rookie_year': 2018,
#   'state_prov': 'New Hampshire',
#   'team_number': 7126,
#   'website': None},
#  {'address': None,
#   'city': 'Farmington',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc7133',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Farmington Senior High School',
#   'nickname': 'STEAM Makers',
#   'postal_code': '03835',
#   'rookie_year': 2018,
#   'state_prov': 'New Hampshire',
#   'team_number': 7133,
#   'website': None},
#  {'address': None,
#   'city': 'Lebanon',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc7212',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Ledyard Charter Academy',
#   'nickname': 'LCS Warriors',
#   'postal_code': '03766',
#   'rookie_year': 2018,
#   'state_prov': 'New Hampshire',
#   'team_number': 7212,
#   'website': 'http://ledyardcharterschool.org'},
#  {'address': None,
#   'city': 'Epping',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc7306',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Epping High School',
#   'nickname': 'Epping High School',
#   'postal_code': '03042',
#   'rookie_year': 2018,
#   'state_prov': 'New Hampshire',
#   'team_number': 7306,
#   'website': None},
#  {'address': None,
#   'city': 'Franklin',
#   'country': 'USA',
#   'gmaps_place_id': None,
#   'gmaps_url': None,
#   'home_championship': {'2017': 'St. Louis', '2018': 'Detroit'},
#   'key': 'frc7314',
#   'lat': None,
#   'lng': None,
#   'location_name': None,
#   'motto': None,
#   'name': 'Franklin High School',
#   'nickname': 'Tornados',
#   'postal_code': '03235',
#   'rookie_year': 2018,
#   'state_prov': 'New Hampshire',
#   'team_number': 7314,
#   'website': None}]

# %%
data[0]["team_number"]
# Out:
# 1071

# %% [markdown]
# Other URLs I will have to parse
#
# Alliance team numbers and scores from:
# https://www.thebluealliance.com/api/v3/event/2018nhdur/matches/simple
#
# team numbers and sort orders from:
# https://www.thebluealliance.com/api/v3/event/2018nhdur/rankings

# %%
import requests
URL= "https://www.thebluealliance.com/api/v3/event/2018nhdur/matches/simple"
auth_key = 'fge7icVbwIkRUkYKFb7Bj045jGELlWspOnCTxJnhkC9jqiLRjE0VBR4ACcez4vxo'

# https://www.dataquest.io/blog/python-api-tutorial/
# https://www.digitalocean.com/community/tutorials/how-to-use-web-apis-in-python-3
# https://www.dataquest.io/blog/python-api-tutorial/
# https://www.dataquest.io/blog/python-api-tutorial/
headers = {"X-TBA-Auth-Key": auth_key}
response = requests.get(URL, headers = headers)
data = response.json()
data
# Out:
# [{'actual_time': 1522524138,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 183,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5813', 'frc138', 'frc5506']},
#    'red': {'dq_team_keys': [],
#     'score': 448,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1519', 'frc319', 'frc4555']}},
#   'comp_level': 'f',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_f1m1',
#   'match_number': 1,
#   'predicted_time': 1522524182,
#   'set_number': 1,
#   'time': 1522524600,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522525136,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 183,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5813', 'frc138', 'frc5506']},
#    'red': {'dq_team_keys': [],
#     'score': 484,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1519', 'frc319', 'frc4555']}},
#   'comp_level': 'f',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_f1m2',
#   'match_number': 2,
#   'predicted_time': 1522525142,
#   'set_number': 1,
#   'time': 1522525380,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522516067,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 142,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6762', 'frc3609', 'frc4929']},
#    'red': {'dq_team_keys': [],
#     'score': 491,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1519', 'frc319', 'frc4555']}},
#   'comp_level': 'qf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qf1m1',
#   'match_number': 1,
#   'predicted_time': 1522516021,
#   'set_number': 1,
#   'time': 1522515600,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522519337,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 160,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6762', 'frc3609', 'frc4929']},
#    'red': {'dq_team_keys': [],
#     'score': 410,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1519', 'frc319', 'frc4555']}},
#   'comp_level': 'qf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qf1m2',
#   'match_number': 2,
#   'predicted_time': 1522519262,
#   'set_number': 1,
#   'time': 1522517280,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522516467,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 381,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1073', 'frc1071', 'frc3323']},
#    'red': {'dq_team_keys': [],
#     'score': 304,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc509', 'frc213', 'frc1247']}},
#   'comp_level': 'qf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qf2m1',
#   'match_number': 1,
#   'predicted_time': 1522516561,
#   'set_number': 2,
#   'time': 1522516020,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522519728,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 335,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1073', 'frc1071', 'frc3323']},
#    'red': {'dq_team_keys': [],
#     'score': 317,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc509', 'frc213', 'frc1247']}},
#   'comp_level': 'qf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qf2m2',
#   'match_number': 2,
#   'predicted_time': 1522519742,
#   'set_number': 2,
#   'time': 1522517700,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522516925,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 265,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1512', 'frc1721', 'frc3597']},
#    'red': {'dq_team_keys': [],
#     'score': 394,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5813', 'frc138', 'frc5506']}},
#   'comp_level': 'qf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qf3m1',
#   'match_number': 1,
#   'predicted_time': 1522516861,
#   'set_number': 3,
#   'time': 1522516440,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522520159,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 268,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1512', 'frc1721', 'frc3597']},
#    'red': {'dq_team_keys': [],
#     'score': 429,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5813', 'frc138', 'frc5506']}},
#   'comp_level': 'qf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qf3m2',
#   'match_number': 2,
#   'predicted_time': 1522520162,
#   'set_number': 3,
#   'time': 1522518120,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522517347,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 336,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6367', 'frc1699', 'frc4546']},
#    'red': {'dq_team_keys': [],
#     'score': 236,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc131', 'frc501', 'frc5422']}},
#   'comp_level': 'qf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qf4m1',
#   'match_number': 1,
#   'predicted_time': 1522517318,
#   'set_number': 4,
#   'time': 1522516860,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522520595,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 327,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6367', 'frc1699', 'frc4546']},
#    'red': {'dq_team_keys': [],
#     'score': 263,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc131', 'frc501', 'frc5422']}},
#   'comp_level': 'qf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qf4m2',
#   'match_number': 2,
#   'predicted_time': 1522520642,
#   'set_number': 4,
#   'time': 1522518540,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522409136,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 241,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4546', 'frc5506', 'frc6895']},
#    'red': {'dq_team_keys': [],
#     'score': 386,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6691', 'frc7314', 'frc319']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm1',
#   'match_number': 1,
#   'predicted_time': 1522423622,
#   'set_number': 1,
#   'time': 1522422000,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522427678,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 343,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6762', 'frc6691', 'frc1073']},
#    'red': {'dq_team_keys': [],
#     'score': 199,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc151', 'frc1699', 'frc166']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm10',
#   'match_number': 10,
#   'predicted_time': 1522427642,
#   'set_number': 1,
#   'time': 1522425780,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522428095,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 214,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3323', 'frc6895', 'frc4925']},
#    'red': {'dq_team_keys': [],
#     'score': 250,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5633', 'frc1512', 'frc7126']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm11',
#   'match_number': 11,
#   'predicted_time': 1522428121,
#   'set_number': 1,
#   'time': 1522426200,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522428598,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 378,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc501', 'frc213', 'frc5506']},
#    'red': {'dq_team_keys': [],
#     'score': 358,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6367', 'frc1519', 'frc4929']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm12',
#   'match_number': 12,
#   'predicted_time': 1522428662,
#   'set_number': 1,
#   'time': 1522426620,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522429008,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 343,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3609', 'frc1307', 'frc509']},
#    'red': {'dq_team_keys': [],
#     'score': 76,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5902', 'frc7314', 'frc3499']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm13',
#   'match_number': 13,
#   'predicted_time': 1522429004,
#   'set_number': 1,
#   'time': 1522427040,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522429495,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 257,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1721', 'frc7212', 'frc4555']},
#    'red': {'dq_team_keys': [],
#     'score': 351,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3323', 'frc3451', 'frc1071']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm14',
#   'match_number': 14,
#   'predicted_time': 1522429442,
#   'set_number': 1,
#   'time': 1522427460,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522432253,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 252,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3597', 'frc501', 'frc5422']},
#    'red': {'dq_team_keys': [],
#     'score': 410,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc319', 'frc6690', 'frc6895']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm15',
#   'match_number': 15,
#   'predicted_time': 1522432323,
#   'set_number': 1,
#   'time': 1522427880,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522432894,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 278,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6691', 'frc7126', 'frc1247']},
#    'red': {'dq_team_keys': [],
#     'score': 322,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4958', 'frc3499', 'frc1699']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm16',
#   'match_number': 16,
#   'predicted_time': 1522432981,
#   'set_number': 1,
#   'time': 1522428300,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522433269,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 234,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc213', 'frc151', 'frc1786']},
#    'red': {'dq_team_keys': [],
#     'score': 397,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1512', 'frc509', 'frc138']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm17',
#   'match_number': 17,
#   'predicted_time': 1522433305,
#   'set_number': 1,
#   'time': 1522428720,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522433643,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 356,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1519', 'frc5813', 'frc6762']},
#    'red': {'dq_team_keys': [],
#     'score': 168,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1307', 'frc6367', 'frc1073']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm18',
#   'match_number': 18,
#   'predicted_time': 1522433675,
#   'set_number': 1,
#   'time': 1522431840,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522434031,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 135,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5902', 'frc1721', 'frc4925']},
#    'red': {'dq_team_keys': [],
#     'score': 338,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4546', 'frc131', 'frc1071']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm19',
#   'match_number': 19,
#   'predicted_time': 1522434124,
#   'set_number': 1,
#   'time': 1522432260,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522424145,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 26,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4929', 'frc5422', 'frc1307']},
#    'red': {'dq_team_keys': [],
#     'score': 363,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4555', 'frc1073', 'frc1247']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm2',
#   'match_number': 2,
#   'predicted_time': 1522424103,
#   'set_number': 1,
#   'time': 1522422420,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522434445,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 208,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5633', 'frc5506', 'frc4929']},
#    'red': {'dq_team_keys': ['frc7212'],
#     'score': 54,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7314', 'frc3609', 'frc7212']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm20',
#   'match_number': 20,
#   'predicted_time': 1522434551,
#   'set_number': 1,
#   'time': 1522432680,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522434903,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 197,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3451', 'frc1512', 'frc166']},
#    'red': {'dq_team_keys': [],
#     'score': 402,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7133', 'frc1073', 'frc319']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm21',
#   'match_number': 21,
#   'predicted_time': 1522435022,
#   'set_number': 1,
#   'time': 1522433100,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522435320,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 324,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1786', 'frc1307', 'frc1247']},
#    'red': {'dq_team_keys': [],
#     'score': 100,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3323', 'frc7126', 'frc151']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm22',
#   'match_number': 22,
#   'predicted_time': 1522435382,
#   'set_number': 1,
#   'time': 1522433520,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522435881,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 378,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5633', 'frc138', 'frc5422']},
#    'red': {'dq_team_keys': [],
#     'score': 252,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1071', 'frc6691', 'frc1721']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm23',
#   'match_number': 23,
#   'predicted_time': 1522435863,
#   'set_number': 1,
#   'time': 1522433940,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522436315,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 296,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4546', 'frc501', 'frc5902']},
#    'red': {'dq_team_keys': [],
#     'score': 344,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4958', 'frc5813', 'frc7133']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm24',
#   'match_number': 24,
#   'predicted_time': 1522436344,
#   'set_number': 1,
#   'time': 1522434360,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522436855,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 281,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc509', 'frc5506', 'frc3451']},
#    'red': {'dq_team_keys': [],
#     'score': 113,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc166', 'frc3609', 'frc3597']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm25',
#   'match_number': 25,
#   'predicted_time': 1522436762,
#   'set_number': 1,
#   'time': 1522434780,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522437184,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 327,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4555', 'frc3499', 'frc131']},
#    'red': {'dq_team_keys': [],
#     'score': 156,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6762', 'frc6895', 'frc6367']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm26',
#   'match_number': 26,
#   'predicted_time': 1522437268,
#   'set_number': 1,
#   'time': 1522435200,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522438115,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 328,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1699', 'frc4925', 'frc7212']},
#    'red': {'dq_team_keys': [],
#     'score': 135,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc213', 'frc7314', 'frc4929']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm27',
#   'match_number': 27,
#   'predicted_time': 1522438081,
#   'set_number': 1,
#   'time': 1522435620,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522438519,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 134,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6690', 'frc151', 'frc6691']},
#    'red': {'dq_team_keys': [],
#     'score': 435,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1071', 'frc1519', 'frc3609']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm28',
#   'match_number': 28,
#   'predicted_time': 1522438623,
#   'set_number': 1,
#   'time': 1522436040,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522438968,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 313,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6762', 'frc5902', 'frc5633']},
#    'red': {'dq_team_keys': [],
#     'score': 116,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6895', 'frc1786', 'frc7126']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm29',
#   'match_number': 29,
#   'predicted_time': 1522438929,
#   'set_number': 1,
#   'time': 1522436460,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522424736,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 219,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6690', 'frc7126', 'frc138']},
#    'red': {'dq_team_keys': [],
#     'score': 137,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5902', 'frc3451', 'frc7133']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm3',
#   'match_number': 3,
#   'predicted_time': 1522424652,
#   'set_number': 1,
#   'time': 1522422840,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522439580,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 228,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1699', 'frc7133', 'frc213']},
#    'red': {'dq_team_keys': [],
#     'score': 192,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5506', 'frc1307', 'frc1721']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm30',
#   'match_number': 30,
#   'predicted_time': 1522439702,
#   'set_number': 1,
#   'time': 1522436880,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522440141,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 198,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc138', 'frc3323', 'frc7314']},
#    'red': {'dq_team_keys': [],
#     'score': 198,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1073', 'frc5422', 'frc4958']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm31',
#   'match_number': 31,
#   'predicted_time': 1522440242,
#   'set_number': 1,
#   'time': 1522437300,
#   'winning_alliance': ''},
#  {'actual_time': 1522441079,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 198,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc166', 'frc1247', 'frc4546']},
#    'red': {'dq_team_keys': [],
#     'score': 387,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3451', 'frc131', 'frc501']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm32',
#   'match_number': 32,
#   'predicted_time': 1522441090,
#   'set_number': 1,
#   'time': 1522437720,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522441816,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 322,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc509', 'frc4929', 'frc319']},
#    'red': {'dq_team_keys': [],
#     'score': 269,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1519', 'frc6690', 'frc4555']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm33',
#   'match_number': 33,
#   'predicted_time': 1522441861,
#   'set_number': 1,
#   'time': 1522438140,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522442312,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 65,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3499', 'frc4925', 'frc6367']},
#    'red': {'dq_team_keys': [],
#     'score': 275,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5813', 'frc3597', 'frc1512']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm34',
#   'match_number': 34,
#   'predicted_time': 1522442344,
#   'set_number': 1,
#   'time': 1522438560,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522442691,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 310,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3609', 'frc6762', 'frc3451']},
#    'red': {'dq_team_keys': [],
#     'score': 179,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7212', 'frc4546', 'frc5422']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm35',
#   'match_number': 35,
#   'predicted_time': 1522442726,
#   'set_number': 1,
#   'time': 1522438980,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522443210,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 111,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6895', 'frc7133', 'frc4929']},
#    'red': {'dq_team_keys': [],
#     'score': 286,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1071', 'frc213', 'frc1307']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm36',
#   'match_number': 36,
#   'predicted_time': 1522443124,
#   'set_number': 1,
#   'time': 1522439400,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522443573,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 328,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc131', 'frc138', 'frc1721']},
#    'red': {'dq_team_keys': [],
#     'score': 156,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7126', 'frc509', 'frc3499']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm37',
#   'match_number': 37,
#   'predicted_time': 1522443842,
#   'set_number': 1,
#   'time': 1522439820,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522444029,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 539,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc151', 'frc319', 'frc1519']},
#    'red': {'dq_team_keys': [],
#     'score': 233,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7314', 'frc5633', 'frc5813']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm38',
#   'match_number': 38,
#   'predicted_time': 1522444023,
#   'set_number': 1,
#   'time': 1522440240,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522444385,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 229,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4555', 'frc6691', 'frc166']},
#    'red': {'dq_team_keys': [],
#     'score': 325,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1247', 'frc4925', 'frc4958']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm39',
#   'match_number': 39,
#   'predicted_time': 1522444442,
#   'set_number': 1,
#   'time': 1522440660,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522425121,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 401,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7212', 'frc1071', 'frc6367']},
#    'red': {'dq_team_keys': [],
#     'score': 211,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4958', 'frc509', 'frc3597']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm4',
#   'match_number': 4,
#   'predicted_time': 1522425275,
#   'set_number': 1,
#   'time': 1522423260,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522444947,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 387,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1699', 'frc6367', 'frc501']},
#    'red': {'dq_team_keys': [],
#     'score': 103,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1786', 'frc3597', 'frc3323']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm40',
#   'match_number': 40,
#   'predicted_time': 1522445043,
#   'set_number': 1,
#   'time': 1522441080,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522445352,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 240,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5506', 'frc7212', 'frc1512']},
#    'red': {'dq_team_keys': [],
#     'score': 361,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1073', 'frc6690', 'frc5902']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm41',
#   'match_number': 41,
#   'predicted_time': 1522445359,
#   'set_number': 1,
#   'time': 1522441500,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522445749,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 313,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7126', 'frc4546', 'frc7314']},
#    'red': {'dq_team_keys': [],
#     'score': 343,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4929', 'frc3609', 'frc4555']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm42',
#   'match_number': 42,
#   'predicted_time': 1522445824,
#   'set_number': 1,
#   'time': 1522441920,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522446159,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 266,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4958', 'frc1071', 'frc151']},
#    'red': {'dq_team_keys': [],
#     'score': 213,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1307', 'frc3451', 'frc3499']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm43',
#   'match_number': 43,
#   'predicted_time': 1522446158,
#   'set_number': 1,
#   'time': 1522442340,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522446556,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 441,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1721', 'frc1512', 'frc1519']},
#    'red': {'dq_team_keys': [],
#     'score': 238,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc131', 'frc1247', 'frc5506']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm44',
#   'match_number': 44,
#   'predicted_time': 1522446617,
#   'set_number': 1,
#   'time': 1522442760,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522446936,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 416,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1073', 'frc1786', 'frc138']},
#    'red': {'dq_team_keys': [],
#     'score': 207,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5633', 'frc509', 'frc4925']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm45',
#   'match_number': 45,
#   'predicted_time': 1522446964,
#   'set_number': 1,
#   'time': 1522443180,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522447279,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 202,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc213', 'frc6367', 'frc6690']},
#    'red': {'dq_team_keys': [],
#     'score': 456,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc319', 'frc6762', 'frc1699']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm46',
#   'match_number': 46,
#   'predicted_time': 1522447343,
#   'set_number': 1,
#   'time': 1522443600,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522447661,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 240,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7133', 'frc3597', 'frc6691']},
#    'red': {'dq_team_keys': [],
#     'score': 294,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5813', 'frc5902', 'frc3323']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm47',
#   'match_number': 47,
#   'predicted_time': 1522447742,
#   'set_number': 1,
#   'time': 1522444020,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522448004,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 176,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5422', 'frc3499', 'frc6895']},
#    'red': {'dq_team_keys': [],
#     'score': 470,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7212', 'frc166', 'frc501']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm48',
#   'match_number': 48,
#   'predicted_time': 1522448065,
#   'set_number': 1,
#   'time': 1522444440,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522448328,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 281,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1071', 'frc7126', 'frc4555']},
#    'red': {'dq_team_keys': [],
#     'score': 400,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1512', 'frc1073', 'frc213']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm49',
#   'match_number': 49,
#   'predicted_time': 1522448407,
#   'set_number': 1,
#   'time': 1522444860,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522425533,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 320,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc131', 'frc3609', 'frc5813']},
#    'red': {'dq_team_keys': [],
#     'score': 167,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1699', 'frc1786', 'frc1512']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm5',
#   'match_number': 5,
#   'predicted_time': 1522425566,
#   'set_number': 1,
#   'time': 1522423680,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522448647,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 407,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3451', 'frc6367', 'frc4546']},
#    'red': {'dq_team_keys': [],
#     'score': 88,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6691', 'frc5633', 'frc1307']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm50',
#   'match_number': 50,
#   'predicted_time': 1522448731,
#   'set_number': 1,
#   'time': 1522445280,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522448997,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 177,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7133', 'frc151', 'frc7314']},
#    'red': {'dq_team_keys': [],
#     'score': 441,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3597', 'frc4925', 'frc131']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm51',
#   'match_number': 51,
#   'predicted_time': 1522449062,
#   'set_number': 1,
#   'time': 1522445700,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522449338,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 20,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5422', 'frc6762', 'frc3323']},
#    'red': {'dq_team_keys': [],
#     'score': 397,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5506', 'frc138', 'frc3609']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm52',
#   'match_number': 52,
#   'predicted_time': 1522449399,
#   'set_number': 1,
#   'time': 1522446120,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522449681,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 408,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1721', 'frc166', 'frc5813']},
#    'red': {'dq_team_keys': [],
#     'score': 179,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1786', 'frc4929', 'frc7212']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm53',
#   'match_number': 53,
#   'predicted_time': 1522449735,
#   'set_number': 1,
#   'time': 1522446540,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522450063,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 198,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc509', 'frc1699', 'frc5902']},
#    'red': {'dq_team_keys': [],
#     'score': 472,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc501', 'frc1247', 'frc319']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm54',
#   'match_number': 54,
#   'predicted_time': 1522450144,
#   'set_number': 1,
#   'time': 1522446960,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522450463,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 106,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4958', 'frc6690', 'frc3609']},
#    'red': {'dq_team_keys': [],
#     'score': 368,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1519', 'frc6895', 'frc131']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm55',
#   'match_number': 55,
#   'predicted_time': 1522450457,
#   'set_number': 1,
#   'time': 1522447380,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522450886,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 187,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7133', 'frc3323', 'frc5633']},
#    'red': {'dq_team_keys': [],
#     'score': 239,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4929', 'frc166', 'frc6762']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm56',
#   'match_number': 56,
#   'predicted_time': 1522450922,
#   'set_number': 1,
#   'time': 1522447800,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522451245,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 320,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4925', 'frc1307', 'frc501']},
#    'red': {'dq_team_keys': [],
#     'score': 174,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7212', 'frc6691', 'frc3451']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm57',
#   'match_number': 57,
#   'predicted_time': 1522451282,
#   'set_number': 1,
#   'time': 1522448220,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522451586,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 411,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3499', 'frc1071', 'frc1073']},
#    'red': {'dq_team_keys': [],
#     'score': 258,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1786', 'frc4546', 'frc6690']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm58',
#   'match_number': 58,
#   'predicted_time': 1522451640,
#   'set_number': 1,
#   'time': 1522448640,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522451975,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 323,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3597', 'frc5902', 'frc1519']},
#    'red': {'dq_team_keys': [],
#     'score': 240,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4555', 'frc1699', 'frc138']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm59',
#   'match_number': 59,
#   'predicted_time': 1522452062,
#   'set_number': 1,
#   'time': 1522449060,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522425955,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 432,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4925', 'frc213', 'frc1519']},
#    'red': {'dq_team_keys': [],
#     'score': 131,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3323', 'frc3499', 'frc166']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm6',
#   'match_number': 6,
#   'predicted_time': 1522425958,
#   'set_number': 1,
#   'time': 1522424100,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522452306,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 397,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5813', 'frc6895', 'frc509']},
#    'red': {'dq_team_keys': [],
#     'score': 307,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1721', 'frc4958', 'frc213']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm60',
#   'match_number': 60,
#   'predicted_time': 1522452369,
#   'set_number': 1,
#   'time': 1522449480,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522452629,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 308,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5422', 'frc319', 'frc7126']},
#    'red': {'dq_team_keys': [],
#     'score': 271,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc151', 'frc6367', 'frc5506']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm61',
#   'match_number': 61,
#   'predicted_time': 1522452699,
#   'set_number': 1,
#   'time': 1522449900,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522453028,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 308,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7314', 'frc1071', 'frc3597']},
#    'red': {'dq_team_keys': [],
#     'score': 273,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1247', 'frc1512', 'frc6762']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm62',
#   'match_number': 62,
#   'predicted_time': 1522453022,
#   'set_number': 1,
#   'time': 1522450320,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522453387,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 452,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc166', 'frc1519', 'frc1786']},
#    'red': {'dq_team_keys': [],
#     'score': 146,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3499', 'frc7212', 'frc7133']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm63',
#   'match_number': 63,
#   'predicted_time': 1522453421,
#   'set_number': 1,
#   'time': 1522450740,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522453759,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 450,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6367', 'frc319', 'frc131']},
#    'red': {'dq_team_keys': [],
#     'score': 180,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4925', 'frc4929', 'frc6691']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm64',
#   'match_number': 64,
#   'predicted_time': 1522453780,
#   'set_number': 1,
#   'time': 1522451160,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522454144,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 271,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7314', 'frc4555', 'frc509']},
#    'red': {'dq_team_keys': [],
#     'score': 347,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7126', 'frc501', 'frc5813']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm65',
#   'match_number': 65,
#   'predicted_time': 1522454151,
#   'set_number': 1,
#   'time': 1522451580,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522503262,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 196,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1307', 'frc4958', 'frc1512']},
#    'red': {'dq_team_keys': [],
#     'score': 317,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3609', 'frc1721', 'frc5422']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm66',
#   'match_number': 66,
#   'predicted_time': 1522503245,
#   'set_number': 1,
#   'time': 1522503000,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522503657,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 280,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6690', 'frc5633', 'frc3451']},
#    'red': {'dq_team_keys': [],
#     'score': 293,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1247', 'frc5902', 'frc213']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm67',
#   'match_number': 67,
#   'predicted_time': 1522503844,
#   'set_number': 1,
#   'time': 1522503420,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522504094,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 142,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc151', 'frc6895', 'frc1073']},
#    'red': {'dq_team_keys': [],
#     'score': 428,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4546', 'frc3323', 'frc1699']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm68',
#   'match_number': 68,
#   'predicted_time': 1522504059,
#   'set_number': 1,
#   'time': 1522503840,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522504478,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 279,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5506', 'frc166', 'frc4925']},
#    'red': {'dq_team_keys': [],
#     'score': 414,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc138', 'frc501', 'frc1071']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm69',
#   'match_number': 69,
#   'predicted_time': 1522504506,
#   'set_number': 1,
#   'time': 1522504260,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522426352,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 223,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3597', 'frc151', 'frc6762']},
#    'red': {'dq_team_keys': [],
#     'score': 313,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc501', 'frc5633', 'frc1721']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm7',
#   'match_number': 7,
#   'predicted_time': 1522426382,
#   'set_number': 1,
#   'time': 1522424520,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522504911,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 370,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3609', 'frc1247', 'frc5633']},
#    'red': {'dq_team_keys': [],
#     'score': 321,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6367', 'frc4555', 'frc7133']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm70',
#   'match_number': 70,
#   'predicted_time': 1522504878,
#   'set_number': 1,
#   'time': 1522504680,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522505323,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 255,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4929', 'frc131', 'frc5902']},
#    'red': {'dq_team_keys': [],
#     'score': 348,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5422', 'frc5813', 'frc151']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm71',
#   'match_number': 71,
#   'predicted_time': 1522505409,
#   'set_number': 1,
#   'time': 1522505100,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522505740,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 220,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7126', 'frc1699', 'frc1307']},
#    'red': {'dq_team_keys': [],
#     'score': 478,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc138', 'frc319', 'frc7212']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm72',
#   'match_number': 72,
#   'predicted_time': 1522505730,
#   'set_number': 1,
#   'time': 1522505520,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522506123,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 190,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3451', 'frc1786', 'frc4958']},
#    'red': {'dq_team_keys': [],
#     'score': 377,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1519', 'frc7314', 'frc5506']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm73',
#   'match_number': 73,
#   'predicted_time': 1522506187,
#   'set_number': 1,
#   'time': 1522505940,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522506487,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 235,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1512', 'frc4546', 'frc6691']},
#    'red': {'dq_team_keys': [],
#     'score': 415,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6762', 'frc213', 'frc509']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm74',
#   'match_number': 74,
#   'predicted_time': 1522506526,
#   'set_number': 1,
#   'time': 1522506360,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522506845,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 300,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1073', 'frc1721', 'frc3323']},
#    'red': {'dq_team_keys': [],
#     'score': 176,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc3499', 'frc3597', 'frc6690']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm75',
#   'match_number': 75,
#   'predicted_time': 1522506885,
#   'set_number': 1,
#   'time': 1522506780,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522507215,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 439,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5813', 'frc5506', 'frc1699']},
#    'red': {'dq_team_keys': [],
#     'score': 32,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6895', 'frc4555', 'frc3451']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm76',
#   'match_number': 76,
#   'predicted_time': 1522507322,
#   'set_number': 1,
#   'time': 1522507200,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522507581,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 299,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc7133', 'frc1519', 'frc7126']},
#    'red': {'dq_team_keys': [],
#     'score': 140,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6691', 'frc5422', 'frc1786']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm77',
#   'match_number': 77,
#   'predicted_time': 1522507609,
#   'set_number': 1,
#   'time': 1522507620,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522507930,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 368,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc509', 'frc3323', 'frc6690']},
#    'red': {'dq_team_keys': [],
#     'score': 273,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4925', 'frc6762', 'frc4546']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm78',
#   'match_number': 78,
#   'predicted_time': 1522507970,
#   'set_number': 1,
#   'time': 1522508040,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522508297,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 401,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1512', 'frc319', 'frc1071']},
#    'red': {'dq_team_keys': [],
#     'score': 209,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc501', 'frc1073', 'frc3609']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm79',
#   'match_number': 79,
#   'predicted_time': 1522508402,
#   'set_number': 1,
#   'time': 1522508460,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522426751,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 450,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc138', 'frc5813', 'frc4546']},
#    'red': {'dq_team_keys': [],
#     'score': 147,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6690', 'frc5422', 'frc1247']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm8',
#   'match_number': 8,
#   'predicted_time': 1522426760,
#   'set_number': 1,
#   'time': 1522424940,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522508746,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 351,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc213', 'frc7212', 'frc3597']},
#    'red': {'dq_team_keys': [],
#     'score': 319,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1307', 'frc131', 'frc151']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm80',
#   'match_number': 80,
#   'predicted_time': 1522508763,
#   'set_number': 1,
#   'time': 1522508880,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522509248,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 234,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1247', 'frc4929', 'frc3499']},
#    'red': {'dq_team_keys': [],
#     'score': 244,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6895', 'frc4958', 'frc5633']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm81',
#   'match_number': 81,
#   'predicted_time': 1522509242,
#   'set_number': 1,
#   'time': 1522509300,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522509737,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 389,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6367', 'frc1721', 'frc7314']},
#    'red': {'dq_team_keys': [],
#     'score': 156,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5902', 'frc138', 'frc166']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm82',
#   'match_number': 82,
#   'predicted_time': 1522509792,
#   'set_number': 1,
#   'time': 1522509720,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522427112,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 417,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc319', 'frc4555', 'frc4958']},
#    'red': {'dq_team_keys': [],
#     'score': 132,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc131', 'frc7133', 'frc1786']}},
#   'comp_level': 'qm',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_qm9',
#   'match_number': 9,
#   'predicted_time': 1522427170,
#   'set_number': 1,
#   'time': 1522425360,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1522521443,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 237,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1073', 'frc1071', 'frc3323']},
#    'red': {'dq_team_keys': [],
#     'score': 458,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1519', 'frc319', 'frc4555']}},
#   'comp_level': 'sf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_sf1m1',
#   'match_number': 1,
#   'predicted_time': 1522521551,
#   'set_number': 1,
#   'time': 1522521360,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522522700,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 83,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1073', 'frc1071', 'frc3323']},
#    'red': {'dq_team_keys': [],
#     'score': 443,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc1519', 'frc319', 'frc4555']}},
#   'comp_level': 'sf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_sf1m2',
#   'match_number': 2,
#   'predicted_time': 1522522742,
#   'set_number': 1,
#   'time': 1522522200,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522522238,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 283,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6367', 'frc1699', 'frc4546']},
#    'red': {'dq_team_keys': [],
#     'score': 341,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5813', 'frc138', 'frc5506']}},
#   'comp_level': 'sf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_sf2m1',
#   'match_number': 1,
#   'predicted_time': 1522522266,
#   'set_number': 2,
#   'time': 1522521780,
#   'winning_alliance': 'red'},
#  {'actual_time': 1522523175,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 275,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc6367', 'frc1699', 'frc4546']},
#    'red': {'dq_team_keys': [],
#     'score': 393,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc5813', 'frc138', 'frc5506']}},
#   'comp_level': 'sf',
#   'event_key': '2018nhdur',
#   'key': '2018nhdur_sf2m2',
#   'match_number': 2,
#   'predicted_time': 1522523161,
#   'set_number': 2,
#   'time': 1522522620,
#   'winning_alliance': 'red'}]

# %%
data[0]
# Out:
# {'actual_time': 1522524138,
#  'alliances': {'blue': {'dq_team_keys': [],
#    'score': 183,
#    'surrogate_team_keys': [],
#    'team_keys': ['frc5813', 'frc138', 'frc5506']},
#   'red': {'dq_team_keys': [],
#    'score': 448,
#    'surrogate_team_keys': [],
#    'team_keys': ['frc1519', 'frc319', 'frc4555']}},
#  'comp_level': 'f',
#  'event_key': '2018nhdur',
#  'key': '2018nhdur_f1m1',
#  'match_number': 1,
#  'predicted_time': 1522524182,
#  'set_number': 1,
#  'time': 1522524600,
#  'winning_alliance': 'red'}

# %%
data[0]["alliances"]["blue"]["team_keys"]
# Out:
# ['frc5813', 'frc138', 'frc5506']

# %% [markdown]
# Record what comp_level the match is and then later use a mask to only keep in the dataframe "qm".
